# %% [markdown]
# # Flavors of Cocoa

# %% [raw]
# The questions that this case study will delve deeper into are:
#
# 1) Which country has the highest chocolate consumption?
# 2) When were the reviews captured?
# 3) Is there a link between the cocoa percentage and the ratings?
# 4) Which countries have the highest ratings?
# 5) Which countries have the lowest ratings?
#
# We'll begin by loading the required libraries and the dataset.

# %%
import numpy as np
import os
import pandas as pd
import sys
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns
sns.set(color_codes=True)

# %% [raw]
# Next we'll load the dataset, located on my desktop:

# %%
cocoa = pd.read_csv("C:/Users/tgameiro/Desktop/flavors_of_cacao.csv")

# %%
cocoa.head()
# Out:
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# 4          2015            70%            France    3.50
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %%
cocoa.dtypes
# Out:
# Company \n(Maker-if known)            object
# Specific Bean Origin\nor Bar Name     object
# REF                                    int64
# Review\nDate                           int64
# Cocoa\nPercent                        object
# Company\nLocation                     object
# Rating                               float64
# Bean\nType                            object
# Broad Bean\nOrigin                    object
# dtype: object

# %%
#We'll convert the Cocoa Percent from a string to a float
cocoa['Cocoa\nPercent'] = cocoa['Cocoa\nPercent'].apply(lambda row: row[:-1]).astype('float')

# %%
cocoa.dtypes
# Out:
# Company \n(Maker-if known)            object
# Specific Bean Origin\nor Bar Name     object
# REF                                    int64
# Review\nDate                           int64
# Cocoa\nPercent                       float64
# Company\nLocation                     object
# Rating                               float64
# Bean\nType                            object
# Broad Bean\nOrigin                    object
# dtype: object

# %%
cocoa.corr()
# Out:
#                      REF  Review\nDate  Cocoa\nPercent    Rating
# REF             1.000000      0.985076        0.037791  0.101030
# Review\nDate    0.985076      1.000000        0.038177  0.099846
# Cocoa\nPercent  0.037791      0.038177        1.000000 -0.164820
# Rating          0.101030      0.099846       -0.164820  1.000000

# %%
cocoa.columns = cocoa.columns.str.replace(' ', '_')

# %%
cocoa.head()
# Out:
#   Company \n(Maker-if_known) Specific_Bean_Origin\nor_Bar_Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate  Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63.0            France    3.75
# 1          2015            70.0            France    2.75
# 2          2015            70.0            France    3.00
# 3          2015            70.0            France    3.50
# 4          2015            70.0            France    3.50
#
#   Broad_Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %%
print("Table 1: Summary of Statistical Measurements")
cocoa.describe(include='all').T
# Out:
# Table 1: Summary of Statistical Measurements
#                                   count unique         top freq     mean  \
# Company \n(Maker-if_known)         1795    416        Soma   47      NaN
# Specific_Bean_Origin\nor_Bar_Name  1795   1039  Madagascar   57      NaN
# REF                                1795    NaN         NaN  NaN   1035.9
# Review\nDate                       1795    NaN         NaN  NaN  2012.33
# Cocoa\nPercent                     1795    NaN         NaN  NaN  71.6983
# Company\nLocation                  1795     60      U.S.A.  764      NaN
# Rating                             1795    NaN         NaN  NaN  3.18593
# Bean\nType                         1794     41              887      NaN
# Broad_Bean\nOrigin                 1794    100   Venezuela  214      NaN
#
#                                         std   min    25%   50%   75%   max
# Company \n(Maker-if_known)              NaN   NaN    NaN   NaN   NaN   NaN
# Specific_Bean_Origin\nor_Bar_Name       NaN   NaN    NaN   NaN   NaN   NaN
# REF                                 552.886     5    576  1069  1502  1952
# Review\nDate                        2.92721  2006   2010  2013  2015  2017
# Cocoa\nPercent                      6.32312    42     70    70    75   100
# Company\nLocation                       NaN   NaN    NaN   NaN   NaN   NaN
# Rating                             0.478062     1  2.875  3.25   3.5     5
# Bean\nType                              NaN   NaN    NaN   NaN   NaN   NaN
# Broad_Bean\nOrigin                      NaN   NaN    NaN   NaN   NaN   NaN

# %% [raw]
# The summary table is very interesting to review.
#
# With this table, we're able to see that the average percent of cocoa in a chocolate bar is around 70%, and the average rating for the chocolate bars is 3.1.
#
# We can see that most of the chocolate bars were reviewed in 2012, with the data collection starting in 2006, up until 2017.
#
# The main location for the cocoa companies is in the U.S.A.
#
# We can also see that the top country that produces the cocoa beans is Venezuala.

# %%
#We will verify if there are any NA's in the dataset
cocoa.isnull().sum(axis=0)
# Out:
# Company \n(Maker-if_known)           0
# Specific_Bean_Origin\nor_Bar_Name    0
# REF                                  0
# Review\nDate                         0
# Cocoa\nPercent                       0
# Company\nLocation                    0
# Rating                               0
# Bean\nType                           1
# Broad_Bean\nOrigin                   1
# dtype: int64

# %% [raw]
# We found that two columns have a single null value in each. This is not significant enough to make a change.
#
# Let's visualize some of the data.
#
# We'll take a look at the countries with the highest amount of chocolate vendors

# %%
cocoa['Company\nLocation'].value_counts().head(15).plot.bar()
plt.xlabel('Countries of Distribution')
plt.ylabel('Count of Chocolate Bars')
print("Companies with the Highest Chocolate Vendors")
# Out:
# Companies with the Highest Chocolate Vendors

# %%
cocoa['Company\nLocation'].value_counts().head(15).plot('barh')
plt.xlabel('Count of Chocolate Bars')
plt.ylabel('Countries of Distribution')
print("Companies with the Highest Chocolate Vendors")
# Out:
# Companies with the Highest Chocolate Vendors

# %% [raw]
# The data clearly shows that the US consumes chocolate far more than any other country of the world.
#
# Let's take a look at the review data

# %%
sns.distplot(cocoa['Review\nDate'])
plt.xlabel('Review Date')
plt.ylabel('Count')
print("Quantity of Reviews by Date")
# Out:
# Quantity of Reviews by Date

# %% [raw]
# Looks like most of the reviews in the dataset were between 2014 and 2016.

# %%
#scatter plot 
var = 'REF'
data = pd.concat([cocoa['Rating'], cocoa[var]], axis=1)
data.plot.scatter(x=var, y='Rating');

# %% [raw]
# We'll now compare the Maximum Cocoa Percentage and the Mean Cocoa Percentage

# %%
cocoa['Cocoa\nPercent'].value_counts()
# Out:
# 70.0     672
# 75.0     222
# 72.0     189
# 65.0      78
# 80.0      72
# 74.0      50
# 68.0      47
# 60.0      43
# 73.0      40
# 85.0      36
# 64.0      34
# 77.0      33
# 71.0      31
# 67.0      27
# 76.0      23
# 66.0      23
# 100.0     20
# 82.0      17
# 78.0      17
# 55.0      16
# 62.0      14
# 63.0      12
# 69.0      10
# 88.0       8
# 90.0       8
# 58.0       8
# 61.0       8
# 81.0       5
# 84.0       4
# 72.5       4
# 83.0       4
# 91.0       3
# 73.5       2
# 56.0       2
# 99.0       2
# 89.0       2
# 86.0       1
# 50.0       1
# 42.0       1
# 87.0       1
# 57.0       1
# 46.0       1
# 53.0       1
# 60.5       1
# 79.0       1
# Name: Cocoa\nPercent, dtype: int64

# %%
cocoa['Cocoa\nPercent'].value_counts().head(20).plot.bar()
plt.xlabel('Cocoa %')
plt.ylabel('Count of Chocolate Bars')
print("Chocolate with the Highest Cocoa %")
# Out:
# Chocolate with the Highest Cocoa %

# %% [raw]
# We see above that most of the chocolates have 70% cocoa. Let's see a little more information...

# %%
cocoa[cocoa['Cocoa\nPercent' ] == 70.0]
# Out:
#         Company \n(Maker-if_known)  Specific_Bean_Origin\nor_Bar_Name   REF  \
# 1                         A. Morin                              Kpime  1676
# 2                         A. Morin                             Atsane  1676
# 3                         A. Morin                              Akata  1680
# 4                         A. Morin                             Quilla  1704
# 5                         A. Morin                           Carenero  1315
# 6                         A. Morin                               Cuba  1315
# 7                         A. Morin                       Sur del Lago  1315
# 8                         A. Morin                     Puerto Cabello  1319
# 9                         A. Morin                            Pablino  1319
# 10                        A. Morin                             Panama  1011
# 11                        A. Morin                         Madagascar  1011
# 12                        A. Morin                             Brazil  1011
# 13                        A. Morin                           Equateur  1011
# 14                        A. Morin                           Colombie  1015
# 15                        A. Morin                           Birmanie  1015
# 16                        A. Morin                   Papua New Guinea  1015
# 17                        A. Morin                              Chuao  1015
# 18                        A. Morin                              Piura  1019
# 19                        A. Morin               Chanchamayo Province  1019
# 21                        A. Morin                            Bolivia   797
# 23                          Acalli            Chulucanas, El Platanal  1462
# 24                          Acalli                  Tumbes, Norandino  1470
# 30              Aequare (Gianduja)          Los Rios, Quevedo, Arriba   370
# 31                        Ah Cacao                            Tabasco   316
# 40                       Alexandre                   Winak Coop, Napo  1944
# 41                       Alexandre                La Dalia, Matagalpa  1944
# 42                       Alexandre                         Tien Giang  1944
# 43                       Alexandre             Makwale Village, Kyela  1944
# 54                           Amano                             Morobe   725
# 55                           Amano                           Dos Rios   470
# ...                            ...                                ...   ...
# 1718          Vietcacao (A. Morin)       Ben Tre, Mekong Delta, MoCay   951
# 1729                         Vivra                               Peru  1720
# 1730                         Vivra                            Ocumare  1720
# 1731                         Vivra                 Dominican Republic  1724
# 1732  Wellington Chocolate Factory                           Conacado  1756
# 1733  Wellington Chocolate Factory            Piura Blanco, Norandino  1756
# 1739                Willie's Cacao                         Los Llanos  1848
# 1745                Willie's Cacao                         San Martin   457
# 1750                     Woodblock                 Maranon, Cajamarca  1243
# 1751                     Woodblock     Camino Verde P., Balao, Guayas  1042
# 1752                     Woodblock                         Gran Couva  1042
# 1753                     Woodblock                            Ecuador   825
# 1754                     Woodblock                         Costa Rica   825
# 1755                     Woodblock                          Sambirano   951
# 1756                     Woodblock                            Ocumare   741
# 1757                     Woodblock                             La Red   769
# 1759                       Xocolla            Sambirano, batch 170102  1948
# 1760                       Xocolla           Hispaniola, batch 170104  1948
# 1761                         Zak's          Papua New Guinea, Batch 2  1574
# 1762                         Zak's       Dominican Republic, Batch D2  1578
# 1763                         Zak's                Madagascar, Batch 2  1578
# 1764                         Zak's                      Peru, Batch 1  1578
# 1765                         Zak's                    Belize, Batch 2  1578
# 1767                 Zart Pralinen                 Millot P., Ambanja  1820
# 1768                 Zart Pralinen                            UNOCACE  1824
# 1771                 Zart Pralinen     Kakao Kamili, Kilombero Valley  1824
# 1781                        Zotter  Satipo Pangoa region, 16hr conche   875
# 1782                        Zotter  Satipo Pangoa region, 20hr conche   875
# 1787                        Zotter                      Santo Domingo   879
# 1790                        Zotter                               Peru   647
#
#       Review\nDate  Cocoa\nPercent Company\nLocation  Rating  \
# 1             2015            70.0            France    2.75
# 2             2015            70.0            France    3.00
# 3             2015            70.0            France    3.50
# 4             2015            70.0            France    3.50
# 5             2014            70.0            France    2.75
# 6             2014            70.0            France    3.50
# 7             2014            70.0            France    3.50
# 8             2014            70.0            France    3.75
# 9             2014            70.0            France    4.00
# 10            2013            70.0            France    2.75
# 11            2013            70.0            France    3.00
# 12            2013            70.0            France    3.25
# 13            2013            70.0            France    3.75
# 14            2013            70.0            France    2.75
# 15            2013            70.0            France    3.00
# 16            2013            70.0            France    3.25
# 17            2013            70.0            France    4.00
# 18            2013            70.0            France    3.25
# 19            2013            70.0            France    3.50
# 21            2012            70.0            France    3.50
# 23            2015            70.0            U.S.A.    3.75
# 24            2015            70.0            U.S.A.    3.75
# 30            2009            70.0           Ecuador    3.00
# 31            2009            70.0            Mexico    3.00
# 40            2017            70.0       Netherlands    3.50
# 41            2017            70.0       Netherlands    3.50
# 42            2017            70.0       Netherlands    3.50
# 43            2017            70.0       Netherlands    3.50
# 54            2011            70.0            U.S.A.    4.00
# 55            2010            70.0            U.S.A.    3.75
# ...            ...             ...               ...     ...
# 1718          2012            70.0            France    3.50
# 1729          2016            70.0            U.S.A.    2.50
# 1730          2016            70.0            U.S.A.    2.50
# 1731          2016            70.0            U.S.A.    3.00
# 1732          2016            70.0       New Zealand    3.50
# 1733          2016            70.0       New Zealand    3.50
# 1739          2016            70.0              U.K.    4.00
# 1745          2009            70.0              U.K.    3.00
# 1750          2014            70.0            U.S.A.    3.00
# 1751          2013            70.0            U.S.A.    3.25
# 1752          2013            70.0            U.S.A.    3.50
# 1753          2012            70.0            U.S.A.    2.50
# 1754          2012            70.0            U.S.A.    3.00
# 1755          2012            70.0            U.S.A.    3.25
# 1756          2011            70.0            U.S.A.    4.00
# 1757          2011            70.0            U.S.A.    3.50
# 1759          2017            70.0            U.S.A.    2.75
# 1760          2017            70.0            U.S.A.    2.50
# 1761          2015            70.0            U.S.A.    3.00
# 1762          2015            70.0            U.S.A.    3.25
# 1763          2015            70.0            U.S.A.    3.25
# 1764          2015            70.0            U.S.A.    3.25
# 1765          2015            70.0            U.S.A.    3.50
# 1767          2016            70.0           Austria    3.50
# 1768          2016            70.0           Austria    2.75
# 1771          2016            70.0           Austria    3.50
# 1781          2012            70.0           Austria    3.00
# 1782          2012            70.0           Austria    3.50
# 1787          2012            70.0           Austria    3.75
# 1790          2011            70.0           Austria    3.75
#
#                 Bean\nType  Broad_Bean\nOrigin
# 1                                         Togo
# 2                                         Togo
# 3                                         Togo
# 4                                         Peru
# 5                  Criollo           Venezuela
# 6                                         Cuba
# 7                  Criollo           Venezuela
# 8                  Criollo           Venezuela
# 9                                         Peru
# 10                                      Panama
# 11                 Criollo          Madagascar
# 12                                      Brazil
# 13                                     Ecuador
# 14                                    Colombia
# 15                                       Burma
# 16                            Papua New Guinea
# 17              Trinitario           Venezuela
# 18                                        Peru
# 19                                        Peru
# 21                                     Bolivia
# 23                                        Peru
# 24                 Criollo                Peru
# 30      Forastero (Arriba)             Ecuador
# 31                 Criollo              Mexico
# 40    Forastero (Nacional)             Ecuador
# 41     Criollo, Trinitario           Nicaragua
# 42              Trinitario             Vietnam
# 43               Forastero            Tanzania
# 54                            Papua New Guinea
# 55                          Dominican Republic
# ...                    ...                 ...
# 1718            Trinitario             Vietnam
# 1729                                      Peru
# 1730                                 Venezuela
# 1731                         Domincan Republic
# 1732            Trinitario  Dominican Republic
# 1733                                      Peru
# 1739                                  Colombia
# 1745                                      Peru
# 1750  Forastero (Nacional)                Peru
# 1751                                   Ecuador
# 1752            Trinitario            Trinidad
# 1753                                   Ecuador
# 1754                                Costa Rica
# 1755            Trinitario          Madagascar
# 1756                                 Venezuela
# 1757                        Dominican Republic
# 1759                                Madagascar
# 1760                        Dominican Republic
# 1761                          Papua New Guinea
# 1762                         Domincan Republic
# 1763            Trinitario          Madagascar
# 1764                                      Peru
# 1765            Trinitario              Belize
# 1767   Criollo, Trinitario          Madagascar
# 1768     Nacional (Arriba)             Ecuador
# 1771   Criollo, Trinitario            Tanzania
# 1781      Criollo (Amarru)                Peru
# 1782      Criollo (Amarru)                Peru
# 1787                        Dominican Republic
# 1790                                      Peru
#
# [672 rows x 9 columns]

# %%
cocoa_seventy=cocoa[cocoa['Cocoa\nPercent' ] == 70.0]
cocoa_seventy.count()
# Out:
# Company \n(Maker-if_known)           672
# Specific_Bean_Origin\nor_Bar_Name    672
# REF                                  672
# Review\nDate                         672
# Cocoa\nPercent                       672
# Company\nLocation                    672
# Rating                               672
# Bean\nType                           671
# Broad_Bean\nOrigin                   672
# dtype: int64

# %%
sns.countplot(x='Rating', data=cocoa_seventy, color='purple')
print("Ratings of Chocolate Bars with 70% Cocoa")
# Out:
# Ratings of Chocolate Bars with 70% Cocoa

# %%
cocoa[cocoa['Cocoa\nPercent' ] == 100.0]
# Out:
#           Company \n(Maker-if_known)      Specific_Bean_Origin\nor_Bar_Name  \
# 125              Artisan du Chocolat                              Venezuela
# 245                           Bonnat                            One Hundred
# 249           Bouga Cacao (Tulicorp)                El Oro, Hacienda de Oro
# 330                          C-Amaro                                Ecuador
# 437                  Claudio Corallo                               Principe
# 449                        Coppeneur                     Ecuador Puristique
# 557                           Domori                     IL100, H. San Jose
# 779                         Habitual                            one hundred
# 828                   Hotel Chocolat         Island Growers, 2012, 120hr c.
# 834       Hotel Chocolat (Coppeneur)  Chanchamayo, Pichanadi, 2012, 60hr c.
# 835       Hotel Chocolat (Coppeneur)      Los Rios, H. Iara, 2012, 120hr c.
# 836       Hotel Chocolat (Coppeneur)               Conacado, 2012, 120hr c.
# 1204                            Ocho                          Sang Yum Coop
# 1251                          Pacari                                    Raw
# 1319                          Pralus              Sambirano Valley, Le 100%
# 1411                        S.A.I.D.                            100 percent
# 1466                          Sirene                 Somia Plantation, 2012
# 1467                          Sirene   Camino Verde P., Balao, Guayas, 2012
# 1720  Vintage Plantations (Tulicorp)      Los Rios, Rancho Grande 2004/2007
# 1741                  Willie's Cacao                 Java, Indonesian Black
#
#        REF  Review\nDate  Cocoa\nPercent Company\nLocation  Rating  \
# 125    486          2010           100.0              U.K.    1.75
# 245     81          2006           100.0            France    1.50
# 249    341          2009           100.0           Ecuador    1.50
# 330   1185          2013           100.0             Italy    3.50
# 437    252          2008           100.0          Sao Tome    1.00
# 449    817          2012           100.0           Germany    1.50
# 557   1109          2013           100.0             Italy    3.00
# 779   1205          2014           100.0            Canada    2.00
# 828   1113          2013           100.0              U.K.    1.75
# 834   1109          2013           100.0              U.K.    2.75
# 835   1113          2013           100.0              U.K.    2.50
# 836   1113          2013           100.0              U.K.    2.75
# 1204  1760          2016           100.0       New Zealand    2.75
# 1251   266          2008           100.0           Ecuador    2.00
# 1319   202          2008           100.0            France    3.00
# 1411   615          2010           100.0             Italy    1.50
# 1466  1502          2015           100.0            Canada    3.00
# 1467  1506          2015           100.0            Canada    3.00
# 1720   153          2007           100.0            U.S.A.    2.00
# 1741  1109          2013           100.0              U.K.    2.25
#
#                 Bean\nType   Broad_Bean\nOrigin
# 125                                   Venezuela
# 245
# 249     Forastero (Arriba)              Ecuador
# 330                                     Ecuador
# 437              Forastero  Sao Tome & Principe
# 449                                     Ecuador
# 557                Criollo            Venezuela
# 779
# 828             Trinitario            St. Lucia
# 834                                        Peru
# 835   Forastero (Nacional)              Ecuador
# 836                          Dominican Republic
# 1204                                      Samoa
# 1251    Forastero (Arriba)              Ecuador
# 1319               Criollo           Madagascar
# 1411
# 1466            Trinitario           Madagascar
# 1467                                    Ecuador
# 1720    Forastero (Arriba)              Ecuador
# 1741                                  Indonesia

# %%
cocoa_hundred=cocoa[cocoa['Cocoa\nPercent' ] == 100.0]
cocoa_hundred.count()
# Out:
# Company \n(Maker-if_known)           20
# Specific_Bean_Origin\nor_Bar_Name    20
# REF                                  20
# Review\nDate                         20
# Cocoa\nPercent                       20
# Company\nLocation                    20
# Rating                               20
# Bean\nType                           20
# Broad_Bean\nOrigin                   20
# dtype: int64

# %%
sns.countplot(x='Rating', data=cocoa_hundred, color='green')
print("Ratings of Chocolate Bars with 100% Cocoa")
# Out:
# Ratings of Chocolate Bars with 100% Cocoa

# %% [raw]
# Let's look at the percent of cocoa with the highest and most consumer ratings

# %%
sns.countplot(x='Rating', data=cocoa)
plt.xlabel('Rating')
plt.ylabel('Count of Users')
plt.title('Number of Users that Rated Chocolate Bars')
print('Count of Chocolate Bar Ratings')
# Out:
# Count of Chocolate Bar Ratings

# %% [raw]
# In this analysis, there are 1795 chocolate bars rated from 63 countries. The most number of ratings that were given was between 3.0 to 3.5, with the highest being 3.5 with a number of around 380 ratings. This shows us that most individuals are giving chocolate bars a rating of a little bit more than satisfactory.
#
# We can see that very few chocolate bars were given the highest rating of 5%, let's see which ones:

# %%
cocoa[cocoa['Rating'] == 5.0]
# Out:
#    Company \n(Maker-if_known) Specific_Bean_Origin\nor_Bar_Name  REF  \
# 78                     Amedei                             Chuao  111
# 86                     Amedei                     Toscano Black   40
#
#     Review\nDate  Cocoa\nPercent Company\nLocation  Rating  Bean\nType  \
# 78          2007            70.0             Italy     5.0  Trinitario
# 86          2006            70.0             Italy     5.0       Blend
#
#    Broad_Bean\nOrigin
# 78          Venezuela
# 86

# %% [raw]
# Both highest rated chocolate comes from Italy and both have 70% cocoa.
#
# We can also see that few were given very low ratings, let's take a look:

# %%
cocoa[cocoa['Rating'] == 1.0]
# Out:
#      Company \n(Maker-if_known) Specific_Bean_Origin\nor_Bar_Name  REF  \
# 326                   Callebaut                            Baking  141
# 437             Claudio Corallo                          Principe  252
# 465          Cote d' Or (Kraft)                Sensations Intense   48
# 1175        Neuhaus (Callebaut)                              Dark  135
#
#       Review\nDate  Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 326           2007            70.0           Belgium     1.0
# 437           2008           100.0          Sao Tome     1.0  Forastero
# 465           2006            70.0           Belgium     1.0
# 1175          2007            73.0           Belgium     1.0
#
#        Broad_Bean\nOrigin
# 326               Ecuador
# 437   Sao Tome & Principe
# 465
# 1175

# %% [raw]
# Three out of four of the lowest rated chocolates are from Belgium, and all have either 70% or close to 70% cocoa percent.
